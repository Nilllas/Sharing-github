# %%
#Import the important libraries
from time import time,sleep
from random import randint
from IPython.core.display import clear_output
from requests import get
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Initialize the variables
start_time = time()
requests = 0
pages = [str(i) for i in range(1,9)]

# %%
#Main Code to extract the data.
for page in pages:
#    print(page)

    url = 'https://www.nasdaq.com/screening/companies-by-industry.aspx?industry=Technology&exchange=NASDAQ&sortname=marketcap&sorttype=1' + page
   
    response = get(url)
    
    #print(response.text[:500])
    # Pause the loop
    sleep(randint(8,15))

        # Monitor the requests
    requests += 1
    elapsed_time = time() - start_time
    print('Request:{}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
    clear_output(wait = True)

    # Throw a warning for non-200 status codes
    if response.status_code != 200:
        print('Request: {}; Status code: {}'.format(requests, response.status_code))

    # Break the loop if the number of requests is greater than expected
    if requests > 50:
        print('Number of requests was greater than expected.')  
        break 
    page_html = BeautifulSoup(response.text, 'html.parser')
    
    # Select all the stocks in the first page
    data = []
    stable = page_html.find('table', attrs={'id':'CompanylistResults'})
    #print(stable)
    rows = stable.find_all('tr')
    #print(rows)
    for row in rows:
        cols = row.find_all('td')
        cols = [ele.text.strip() for ele in cols]
        data.append([ele for ele in cols if ele]) # Get rid of empty values
    #print(data)
# Out:
# <!doctype html>
# <html lang="en-us" class="inner no-js" xmlns:og="https://ogp.me/ns#" xmlns:fb="https://www.facebook.com/2008/fbml">
# <head>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','
# Request:8; Frequency: 0.0674606766908757 requests/s

# %%
print(data)
# Out:
# [[], ['Ameri Holdings, Inc.', 'AMRHW', 'n/a', 'United States', 'n/a', 'Semiconductors'], ['AMRHW Stock Quote\n\n\r\n\t\t\t\t                AMRHW Ratings\n\n\r\n\t\t\t\t                AMRHW Stock Report'], ['Creative Realities, Inc.', 'CREXW', 'n/a', 'United States', 'n/a', 'EDP Services'], ['CREXW Stock Quote\n\n\r\n\t\t\t\t                CREXW Ratings\n\n\r\n\t\t\t\t                CREXW Stock Report'], ['Envision Solar International, Inc.', 'EVSIW', 'n/a', 'United States', 'n/a', 'Semiconductors'], ['EVSIW Stock Quote\n\n\r\n\t\t\t\t                EVSIW Ratings\n\n\r\n\t\t\t\t                EVSIW Stock Report'], ['FlexShopper, Inc.', 'FPAYW', 'n/a', 'United States', 'n/a', 'Diversified Commercial Services'], ['FPAYW Stock Quote\n\n\r\n\t\t\t\t                FPAYW Ratings\n\n\r\n\t\t\t\t                FPAYW Stock Report'], ['General Finance Corporation', 'GFNSL', 'n/a', 'United States', 'n/a', 'Diversified Commercial Services'], ['GFNSL Stock Quote\n\n\r\n\t\t\t\t                GFNSL Ratings\n\n\r\n\t\t\t\t                GFNSL Stock Report'], ['GTY Technology Holdings, Inc.', 'GTYHW', 'n/a', 'United States', '2016', 'EDP Services'], ['GTYHW Stock Quote\n\n\r\n\t\t\t\t                GTYHW Ratings\n\n\r\n\t\t\t\t                GTYHW Stock Report'], ['MTech Acquisition Corp.', 'MTECU', 'n/a', 'United States', '2018', 'EDP Services'], ['MTECU Stock Quote\n\n\r\n\t\t\t\t                MTECU Ratings\n\n\r\n\t\t\t\t                MTECU Stock Report'], ['MTech Acquisition Corp.', 'MTECW', 'n/a', 'United States', '2018', 'EDP Services'], ['MTECW Stock Quote\n\n\r\n\t\t\t\t                MTECW Ratings\n\n\r\n\t\t\t\t                MTECW Stock Report'], ['Phunware, Inc.', 'PHUNW', 'n/a', 'Greece', '2016', 'EDP Services'], ['PHUNW Stock Quote\n\n\r\n\t\t\t\t                PHUNW Ratings\n\n\r\n\t\t\t\t                PHUNW Stock Report'], ['FRONTEO, Inc.', 'FTEO', '$538281.6', '57,264', 'Japan', '2013', 'EDP Services'], ['FTEO Stock Quote\n\n\r\n\t\t\t\t                FTEO Ratings\n\n\r\n\t\t\t\t                FTEO Stock Report'], ['Safe-T Group Ltd.', 'SFET', '$2.14M', '995,143', 'Israel', '2018', 'Computer Software: Prepackaged Software'], ['SFET Stock Quote\n\n\r\n\t\t\t\t                SFET Ratings\n\n\r\n\t\t\t\t                SFET Stock Report'], ['JMU Limited', 'JMU', '$3.81M', '2,575,528', 'China', '2015', 'EDP Services'], ['JMU Stock Quote\n\n\r\n\t\t\t\t                JMU Ratings\n\n\r\n\t\t\t\t                JMU Stock Report'], ['Sphere 3D Corp.', 'ANY', '$4.66M', 'Canada', 'n/a', 'EDP Services'], ['ANY Stock Quote\n\n\r\n\t\t\t\t                ANY Ratings\n\n\r\n\t\t\t\t                ANY Stock Report'], ['Inpixon', 'INPX', '$5.24M', 'United States', '2014', 'EDP Services'], ['INPX Stock Quote\n\n\r\n\t\t\t\t                INPX Ratings\n\n\r\n\t\t\t\t                INPX Stock Report'], ['Superconductor Technologies Inc.', 'SCON', '$5.67M', 'United States', '1993', 'Radio And Television Broadcasting And Communications Equipment'], ['SCON Stock Quote\n\n\r\n\t\t\t\t                SCON Ratings\n\n\r\n\t\t\t\t                SCON Stock Report'], ['Eltek Ltd.', 'ELTK', '$5.89M', 'Israel', '1997', 'Electrical Products'], ['ELTK Stock Quote\n\n\r\n\t\t\t\t                ELTK Ratings\n\n\r\n\t\t\t\t                ELTK Stock Report'], ['BroadVision, Inc.', 'BVSN', '$5.97M', 'United States', '1996', 'Computer Software: Prepackaged Software'], ['BVSN Stock Quote\n\n\r\n\t\t\t\t                BVSN Ratings\n\n\r\n\t\t\t\t                BVSN Stock Report'], ['Foresight Autonomous Holdings Ltd.', 'FRSX', '$6.33M', '5,188,399', 'Israel', 'n/a', 'Computer Software: Prepackaged Software'], ['FRSX Stock Quote\n\n\r\n\t\t\t\t                FRSX Ratings\n\n\r\n\t\t\t\t                FRSX Stock Report'], ['Formula Systems (1985) Ltd.', 'FORTY', '$7.21M', '144,666', 'Israel', 'n/a', 'EDP Services'], ['FORTY Stock Quote\n\n\r\n\t\t\t\t                FORTY Ratings\n\n\r\n\t\t\t\t                FORTY Stock Report'], [ ...

# %%
#Assign to dataframe for visualization

stocks = pd.DataFrame(list(data))
stocks.columns = ['Name', 'Symbol','Market Cap','Country','IPO Year','Sector','Sub Sector']
print(stocks.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 7 columns):
# Name          100 non-null object
# Symbol        50 non-null object
# Market Cap    50 non-null object
# Country       50 non-null object
# IPO Year      50 non-null object
# Sector        50 non-null object
# Sub Sector    7 non-null object
# dtypes: object(7)
# memory usage: 2.8+ KB
# None

# %%
stocks.describe()
# Out:
#                            Name Symbol Market Cap        Country IPO Year  \
# count                       100     50         50             50       50
# unique                       96     50         42             13       17
# top     MTech Acquisition Corp.   EVOL        n/a  United States      n/a
# freq                          2      1          9             32       28
#
#               Sector    Sub Sector
# count             50             7
# unique            17             4
# top     EDP Services  EDP Services
# freq              11             3

# %%
import pandas_profiling 
pandas_profiling.ProfileReport(stocks)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>7 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>101 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>49.5% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>2.8 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>28.4 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>7 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_Country"><code>Country</code></a> has 51 / 50.5% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_IPO Year"><code>IPO Year</code></a> has 51 / 50.5% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_Market Cap"><code>Market Cap</code></a> has 51 / 50.5% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_Name"><code>Name</code></a> has a high cardinality: 97 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_Sector"><code>Sector</code></a> has 51 / 50.5% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_Sub Sector"><code>Sub Sector</code></a> has 94 / 93.1% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_Symbol"><code>Symbol</code></a> has 51 / 50.5% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_Symbol"><code>Symbol</code></a> has a high cardinality: 51 distinct values  <span class="label label-warning">Warning</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_Country">Country<br/>
